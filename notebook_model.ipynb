# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import json
import joblib
import warnings
import random
from pathlib import Path
from datetime import datetime

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GroupShuffleSplit
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import (accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve, precision_recall_curve, average_precision_score, r2_score)

# %%
# Configurações de exibição do pandas
pd.set_option('display.max_columns', 200)
pd.set_option('display.width', 200)

# %% [markdown]
# ## Funções

# %%
def normalize_columns(df):
    out = df.copy()
    out.columns = [c.strip() for c in out.columns]
    return out

def isFileExists(file_path):
    if os.path.exists(file_path):
        return True
    else:
        print("Arquivo não encontrado:", file_path)
        return False

def eval_model(name, model, X_test, y_test):
    proba = model.predict_proba(X_test)[:, 1]

    precision, recall, thresholds = precision_recall_curve(y_test, proba)
    f1 = 2*(precision*recall)/(precision+recall+1e-9)
    best_threshold = thresholds[np.argmax(f1)]

    pred = (proba >= best_threshold).astype(int)

    roc = roc_auc_score(y_test, proba)
    ap = average_precision_score(y_test, proba)

    print(f'\n=== {name} ===')
    print('ROC-AUC:', round(roc, 4))
    print('PR-AUC :', round(ap, 4))
    print(f'\nConfusion matrix:\n', confusion_matrix(y_test, pred))
    print(f'\nReport:\n', classification_report(y_test, pred, digits=3))

    # Curvas
    fpr, tpr, _ = roc_curve(y_test, proba)
    pr, rc, _ = precision_recall_curve(y_test, proba)

    plt.figure(figsize=(5, 4))
    plt.plot(fpr, tpr)
    plt.plot([0, 1], [0, 1], linestyle='--')
    plt.title(f'ROC - {name}')
    plt.xlabel('FPR')
    plt.ylabel('TPR')
    plt.show()

    plt.figure(figsize=(5, 4))
    plt.plot(rc, pr)
    plt.title(f'Precision-Recall - {name}')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.show()

# %% [markdown]
# ## Carregamento dos dados

# %%
datasetFile = "data/BASE DE DADOS PEDE 2024 - DATATHON.xlsx"

if not isFileExists(datasetFile): exit()

# Ler todas as abas
xls = pd.ExcelFile(datasetFile)
print('Sheets:', xls.sheet_names)

dfs = {}
for sh in xls.sheet_names:
    dfs[sh] = xls.parse(sh)
    print(sh, dfs[sh].shape)

# Preview
for sh, df_ in dfs.items():
    print('===', sh, '===')
    display(df_.head(3))
# Out:
# Sheets: ['PEDE2022', 'PEDE2023', 'PEDE2024']
# PEDE2022 (860, 42)
# PEDE2023 (1014, 48)
# PEDE2024 (1156, 50)
# === PEDE2022 ===
#      RA  Fase Turma     Nome  Ano nasc  Idade 22  Gênero  Ano ingresso Instituição de ensino  Pedra 20  Pedra 21  Pedra 22  INDE 22   Cg  Cf  Ct  Nº Av   Avaliador1                Rec Av1  \
# 0  RA-1     7     A  Aluno-1      2003        19  Menina          2016        Escola Pública  Ametista  Ametista   Quartzo    5.783  753  18  10      4  Avaliador-5  Mantido na Fase atual
# 1  RA-2     7     A  Aluno-2      2005        17  Menina          2017          Rede Decisão  Ametista  Ametista  Ametista    7.055  469   8   3      4  Avaliador-5      Promovido de Fase
# 2  RA-3     7     A  Aluno-3      2005        17  Menina          2016          Rede Decisão  Ametista  Ametista     Ágata    6.591  629  13   6      4  Avaliador-5      Promovido de Fase
#
#      Avaliador2                    Rec Av2    Avaliador3                    Rec Av3    Avaliador4                    Rec Av4  IAA  IEG  IPS    Rec Psicologia  IDA  Matem  Portug  Inglês Indicado  \
# 0  Avaliador-27  Promovido de Fase + Bolsa  Avaliador-28          Promovido de Fase  Avaliador-31      Mantido na Fase atual  8.3  4.1  5.6  Requer avaliação  4.0    2.7     3.5     6.0      Sim
# 1  Avaliador-27  Promovido de Fase + Bolsa  Avaliador-28          Promovido de Fase  Avaliador-31  Promovido de Fase + Bolsa  8.8  5.2  6.3    Sem limitações  6.8    6.3     4.5     9.7      Não
# 2  Avaliador-27  Promovido de Fase + Bolsa  Avaliador-28  Promovido de Fase + Bolsa  Avaliador-31  Promovido de Fase + Bolsa  0.0  7.9  5.6    Sem limitações  5.6    5.8     4.0     6.9      Não
#
#   Atingiu PV    IPV   IAN               Fase ideal  Defas                                       Destaque IEG                                       Destaque IDA  \
# 0        Não  7.278   5.0  Fase 8 (Universitários)     -1  Melhorar: Melhorar a sua entrega de lições de ...  Melhorar: Empenhar-se mais nas aulas e avaliaç...
# 1        Não  6.778  10.0           Fase 7 (3º EM)      0  Melhorar: Melhorar a sua entrega de lições de ...  Melhorar: Empenhar-se mais nas aulas e avaliaç...
# 2        Não  7.556  10.0           Fase 7 (3º EM)      0    Destaque: A sua boa entrega das lições de casa.  Melhorar: Empenhar-se mais nas aulas e avaliaç...
#
#                                         Destaque IPV
# 0  Melhorar: Integrar-se mais aos Princípios Pass...
# 1  Melhorar: Integrar-se mais aos Princípios Pass...
# 2  Destaque: A sua boa integração aos Princípios ...
# === PEDE2023 ===
#        RA  Fase  INDE 2023 Pedra 2023           Turma Nome Anonimizado Data de Nasc Idade     Gênero  Ano ingresso Instituição de ensino Pedra 20 Pedra 21 Pedra 22  Pedra 23  INDE 22  INDE 23  Cg  \
# 0  RA-861  ALFA    9.31095    Topázio  ALFA A - G0/G1        Aluno-861    6/17/2015     8   Feminino          2023               Pública      NaN      NaN      NaN       NaN      NaN      NaN NaN
# 1  RA-862  ALFA    8.22120    Topázio  ALFA A - G0/G1        Aluno-862    5/31/2014     9  Masculino          2023               Pública      NaN      NaN      NaN       NaN      NaN      NaN NaN
# 2  RA-863  ALFA    5.92975    Quartzo  ALFA A - G0/G1        Aluno-863    2/25/2016     7  Masculino          2023               Pública      NaN      NaN      NaN       NaN      NaN      NaN NaN
#
#    Cf  Ct  Nº Av    Avaliador1  Rec Av1   Avaliador2  Rec Av2 Avaliador3  Rec Av3 Avaliador4  Rec Av4  IAA   IEG   IPS     IPP  Rec Psicologia  IDA  Mat  Por  Ing  Indicado  Atingiu PV    IPV   IAN  \
# 0 NaN NaN    2.0  Avaliador-11      NaN  Avaliador-2      NaN        NaN      NaN        NaN      NaN  9.5  10.0  8.13  8.4375             NaN  9.6  9.8  9.4  NaN       NaN         NaN  8.920  10.0
# 1 NaN NaN    2.0  Avaliador-11      NaN  Avaliador-2      NaN        NaN      NaN        NaN      NaN  8.5   9.1  8.14  7.5000             NaN  8.9  8.5  9.2  NaN       NaN         NaN  8.585   5.0
# 2 NaN NaN    2.0  Avaliador-11      NaN  Avaliador-2      NaN        NaN      NaN        NaN      NaN  0.0   7.6  3.14  5.9375             NaN  6.3  7.0  5.5  NaN       NaN         NaN  6.260  10.0
#
#              Fase Ideal  Defasagem  Destaque IEG  Destaque IDA  Destaque IPV  Destaque IPV.1
# 0    ALFA (1° e 2° ano)          0           NaN           NaN           NaN             NaN
# 1  Fase 1 (3° e 4° ano)         -1           NaN           NaN           NaN             NaN
# 2    ALFA (1° e 2° ano)          0           NaN           NaN           NaN             NaN
# === PEDE2024 ===
#         RA  Fase INDE 2024 Pedra 2024           Turma Nome Anonimizado Data de Nasc  Idade     Gênero  Ano ingresso Instituição de ensino Pedra 20 Pedra 21 Pedra 22 Pedra 23  INDE 22  INDE 23  Cg  \
# 0  RA-1275  ALFA  7.611367   Ametista  ALFA A - G0/G1       Aluno-1275   2016-07-28      8  Masculino          2024               Pública      NaN      NaN      NaN      NaN      NaN      NaN NaN
# 1  RA-1276  ALFA  8.002867    Topázio  ALFA A - G0/G1       Aluno-1276   2016-10-16      8   Feminino          2024               Pública      NaN      NaN      NaN      NaN      NaN      NaN NaN
# 2  RA-1277  ALFA    7.9522   Ametista  ALFA A - G0/G1       Aluno-1277   2016-08-16      8  Masculino          2024               Pública      NaN      NaN      NaN      NaN      NaN      NaN NaN
#
#    Cf  Ct  Nº Av    Avaliador1  Rec Av1   Avaliador2  Rec Av2   Avaliador3 Avaliador4 Avaliador5 Avaliador6     IAA       IEG   IPS    IPP  Rec Psicologia  IDA   Mat  Por  Ing  Indicado  Atingiu PV  \
# 0 NaN NaN      3  Avaliador-11      NaN  Avaliador-2      NaN  Avaliador-9        NaN        NaN        NaN  10.002  8.666667  6.26  5.625             NaN  8.0  10.0  6.0  NaN       NaN         NaN
# 1 NaN NaN      3  Avaliador-11      NaN  Avaliador-2      NaN  Avaliador-9        NaN        NaN        NaN  10.002  9.333333  3.76  7.500             NaN  8.0  10.0  6.0  NaN       NaN         NaN
# 2 NaN NaN      3  Avaliador-11      NaN  Avaliador-2      NaN  Avaliador-9        NaN        NaN        NaN  10.002  9.083333  3.76  7.500             NaN  8.0  10.0  6.0  NaN       NaN         NaN
#
#         IPV   IAN          Fase Ideal  Defasagem  Destaque IEG  Destaque IDA  Destaque IPV                             Escola Ativo/ Inativo Ativo/ Inativo.1
# 0  5.446667  10.0  ALFA (1° e 2° ano)          0           NaN           NaN           NaN              EE Chácara Florida II       Cursando         Cursando
# 1  7.050000  10.0  ALFA (1° e 2° ano)          0           NaN           NaN           NaN              EE Chácara Florida II       Cursando         Cursando
# 2  7.046667  10.0  ALFA (1° e 2° ano)          0           NaN           NaN           NaN  EE Dom Pedro Villas Boas de Souza       Cursando         Cursando

# %% [markdown]
# ## União das bases

# %%
p22 = normalize_columns(dfs['PEDE2022']).copy()
p23 = normalize_columns(dfs['PEDE2023']).copy()
p24 = normalize_columns(dfs['PEDE2024']).copy()

p22['ano_ref'] = 2022
p23['ano_ref'] = 2023
p24['ano_ref'] = 2024

# Padronizar alguns nomes comuns
rename_22 = {
    'Nome': 'Nome_Anon',
    'Idade 22': 'Idade',
    'INDE 22': 'INDE',
    'Matem': 'Mat',
    'Portug': 'Por',
    'Inglês': 'Ing',
    'Defas': 'Defasagem',
}
rename_23 = {
    'Nome Anonimizado': 'Nome_Anon',
    'Data de Nasc': 'Data_Nasc',
    'Instituição de ensino': 'Instituicao_Ensino',
    'INDE 2023': 'INDE',
}
rename_24 = {
    'Nome Anonimizado': 'Nome_Anon',
    'Data de Nasc': 'Data_Nasc',
    'Instituição de ensino': 'Instituicao_Ensino',
    'INDE 2024': 'INDE',
}

p22 = p22.rename(columns=rename_22)
p23 = p23.rename(columns=rename_23)
p24 = p24.rename(columns=rename_24)

# Unir
base = pd.concat([p22, p23, p24], ignore_index=True)

colunas_desejadas = ['RA', 'Nome_Anon', 'Idade', 'Gênero', 'INDE', 'IAA', 'IEG',
                     'IPS', 'IDA', 'IPV', 'IAN', 'Defasagem', 'Fase Ideal', 'IPP', 'ano_ref', 'Fase']

base = base[colunas_desejadas].copy()

# Ajustes finais de tipos
base['RA'] = base['RA'].astype(str)
base['ano_ref'] = base['ano_ref'].astype(int)

# Datas (quando existir)
if 'Data_Nasc' in base.columns:
    base['Data_Nasc'] = pd.to_datetime(base['Data_Nasc'], errors='coerce')

# Padronizar genero (tem "Menina"/"Feminino" etc)
base['Gênero'] = base['Gênero'].astype(str).str.strip().replace(
    {'Feminino': 'Menina', 'Masculino': 'Menino'})

print('Base unificada:', base.shape)
base.info()
base.describe(include='all')
display(base.head())
# Out:
# Base unificada: (3030, 16)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3030 entries, 0 to 3029
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   RA          3030 non-null   object
#  1   Nome_Anon   3030 non-null   object
#  2   Idade       3030 non-null   object
#  3   Gênero      3030 non-null   object
#  4   INDE        2883 non-null   object
#  5   IAA         2865 non-null   float64
#  6   IEG         2954 non-null   float64
#  7   IPS         2859 non-null   float64
#  8   IDA         2852 non-null   float64
#  9   IPV         2852 non-null   float64
#  10  IAN         3030 non-null   float64
#  11  Defasagem   3030 non-null   int64
#  12  Fase Ideal  2170 non-null   object
#  13  IPP         1992 non-null   float64
#  14  ano_ref     3030 non-null   int64
#  15  Fase        3030 non-null   object
# dtypes: float64(7), int64(2), object(7)
# memory usage: 378.9+ KB
#      RA Nome_Anon Idade  Gênero   INDE  IAA  IEG  IPS  IDA    IPV   IAN  Defasagem Fase Ideal  IPP  ano_ref Fase
# 0  RA-1   Aluno-1    19  Menina  5.783  8.3  4.1  5.6  4.0  7.278   5.0         -1        NaN  NaN     2022    7
# 1  RA-2   Aluno-2    17  Menina  7.055  8.8  5.2  6.3  6.8  6.778  10.0          0        NaN  NaN     2022    7
# 2  RA-3   Aluno-3    17  Menina  6.591  0.0  7.9  5.6  5.6  7.556  10.0          0        NaN  NaN     2022    7
# 3  RA-4   Aluno-4    17  Menino  5.951  8.8  4.5  5.6  5.0  5.278  10.0          0        NaN  NaN     2022    7
# 4  RA-5   Aluno-5    17  Menina  7.427  7.9  8.6  5.6  5.2  7.389  10.0          0        NaN  NaN     2022    7

# %% [markdown]
# ## Pré-processamento dos dados

# %%
# Nulos
nulls = (base.isna().mean().sort_values(ascending=False) * 100).round(1)
display(nulls.to_frame('% nulos').head(25))

# Duplicados
dups = base.duplicated(subset=['RA', 'ano_ref']).sum()
print('Duplicados (RA, ano_ref):', dups)

# Ranges basicos
for c in ['INDE', 'IAA', 'IEG', 'IPS', 'IDA', 'IPV', 'IAN', 'Mat', 'Por', 'Ing']:
    if c in base.columns:
        s = pd.to_numeric(base[c], errors='coerce')
        print(c, 'min=', np.nanmin(s.values), 'max=', np.nanmax(s.values))
# Out:
#             % nulos
# IPP            34.3
# Fase Ideal     28.4
# IPV             5.9
# IDA             5.9
# IPS             5.6
# IAA             5.4
# INDE            4.9
# IEG             2.5
# RA              0.0
# Nome_Anon       0.0
# Idade           0.0
# Gênero          0.0
# Defasagem       0.0
# IAN             0.0
# ano_ref         0.0
# Fase            0.0
# Duplicados (RA, ano_ref): 0
# INDE min= 3.032 max= 9.531325
# IAA min= 0.0 max= 10.002
# IEG min= 0.0 max= 10.0
# IPS min= 2.5 max= 10.0
# IDA min= 0.0 max= 10.0
# IPV min= 2.5 max= 10.01
# IAN min= 2.5 max= 10.0

# %% [markdown]
# ## Feature Enginnering

# %%
# Definir target de risco (ajuste os cortes)

tmp = base.copy()

tmp = tmp.sort_values(['RA', 'ano_ref'])

tmp['risco'] = (tmp['IAN'] > 5).astype(int)

target_col = tmp['risco'].name

assert target_col is not None, "Coluna alvo não encontrada"

print(tmp['risco'].value_counts(dropna=False))

feature_cols = [
    'Idade', 'Fase', 'Gênero',
    'IAA', 'IEG', 'IPS', 'IPP', 'IDA', 'IPV', 'INDE',
    'Mat', 'Por', 'Ing'
]

# Manter só as que existem
feature_cols = [c for c in feature_cols if c in tmp.columns]

X = tmp[feature_cols].copy()
y = tmp['risco'].copy()

# Lista de colunas que deveriam ser numéricas
potential_num_cols = ['IAA', 'IEG', 'IPS', 'IPP', 'IDA', 'IPV', 'INDE', 'Idade']

# Converter colunas numéricas para o tipo correto, coercing erros para NaN
# Isso resolve o problema de strings como 'INCLUIR' em colunas numéricas
num_cols = []
for col in potential_num_cols:
    if col in X.columns:
        X[col] = pd.to_numeric(X[col], errors='coerce')
        num_cols.append(col)

# Categorical columns são as que sobram de feature_cols
cat_cols = [c for c in feature_cols if c not in num_cols]

# Converter explicitamente colunas categóricas para string para evitar TypeErrors no OneHotEncoder
for col in cat_cols:
    if col in X.columns:
        X[col] = X[col].astype(str)

print('Num:', num_cols)
print('Cat:', cat_cols)

tmp.to_csv('data/dados_tratados.csv',
          sep=';',
          index=False,
          encoding='utf-8-sig')
# Out:
# risco
# 0    1687
# 1    1343
# Name: count, dtype: int64
# Num: ['IAA', 'IEG', 'IPS', 'IPP', 'IDA', 'IPV', 'INDE', 'Idade']
# Cat: ['Fase', 'Gênero']

# %% [markdown]
# ## Treinamento do modelo

# %%
warnings.filterwarnings("ignore")
np.random.seed(42)
random.seed(42)
pathNameArtifacts = "model"

gss = GroupShuffleSplit(test_size=0.2, random_state=42)

train_idx, test_idx = next(gss.split(X, y, groups=tmp['RA']))

# Split
X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

# Preprocess
numeric_tf = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_tf = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

preprocess = ColumnTransformer(
    transformers=[
        ('num', numeric_tf, num_cols),
        ('cat', categorical_tf, cat_cols)
    ],
    remainder='drop'
)

# Modelo
rf = RandomForestClassifier(
    n_estimators=400,
    random_state=42,
    class_weight='balanced',
    n_jobs=-1
)

pipe_rf = Pipeline(steps=[('prep', preprocess), ('model', rf)])

# Treinar
pipe_rf.fit(X_train, y_train)

# Salvar informações das features
with open(os.path.join(pathNameArtifacts, "feature_info.json"), "w", encoding="utf-8") as f:
    json.dump({"num_cols": num_cols, "cat_cols": cat_cols, "target": target_col,
               "classes": sorted(y.unique().tolist())}, f, ensure_ascii=False, indent=2)

print('Treino ok')
# Out:
# Treino ok

# %% [markdown]
# ## Carregar Modelo escolhido

# %%
eval_model('RandomForest', pipe_rf, X_test, y_test)

with open(os.path.join(pathNameArtifacts, "feature_info.json"), "r", encoding="utf-8") as f:
    finfo = json.load(f)

MODEL_OUT = Path('model/best_model_{best_name}.joblib'.format(best_name='rf'))
joblib.dump(pipe_rf, MODEL_OUT)

num_cols = finfo.get("num_cols", [])
cat_cols = finfo.get("cat_cols", [])
tgt = finfo.get("target")

print('Modelo escolhido salvo em:', MODEL_OUT)
# Out:
# === RandomForest ===
# ROC-AUC: 0.9697
# PR-AUC : 0.9668
#
# Confusion matrix:
#  [[295  33]
#  [ 15 246]]
#
# Report:
#                precision    recall  f1-score   support
#
#            0      0.952     0.899     0.925       328
#            1      0.882     0.943     0.911       261
#
#     accuracy                          0.919       589
#    macro avg      0.917     0.921     0.918       589
# weighted avg      0.921     0.919     0.919       589
# Modelo escolhido salvo em: model\best_model_rf.joblib

# %% [markdown]
# ## Acurácia

# %%
# Avaliação no conjunto de teste
y_pred = pipe_rf.predict(X_test)
acc = accuracy_score(y_test, y_pred)

print('Acurácia no teste:', round(acc, 4))
# Out:
# Acurácia no teste: 0.9049

# %% [markdown]
# ## Gera Relatório

# %%
print('RELATÓRIOS')

html_path = 'reports/Relatorio_TechChallenge_Passos.html'
md_path = 'reports/Relatorio_TechChallenge_Passos.md'
# Resumo dos indicadores (preenche dinamicamente com variáveis calculadas no notebook)
key_insights = [
    f'Tamanho da base: {len(base)}',
    f'Acurácia (teste): {round(acc,4) if 'acc' in globals() else 'não calculada'}',
    'Principais variáveis analisadas: IAN, IDA, IEG, IPS, IPP, IPV, INDE',
    'Modelo de risco: pipeline com RandomForest (salvo em model/)'
]

html = ('<!DOCTYPE html><html lang=pt-br><head><meta charset=utf-8/><title>Relatório — Tech Challenge Passos</title>'
        + '<style>body{font-family:Arial;margin:2rem}h1,h2{color:#222}ul{line-height:1.4}</style></head><body>'
        + '<h1>Relatório — Tech Challenge (Passos)</h1>'
        + f"<p><strong>Data:</strong> {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}</p>"
        + '<h2>Resumo</h2>'
        + '<p>Este relatório sumariza as análises realizadas sobre defasagem e desempenho acadêmico (IAN, IDA, IEG, IPS, IPP, IPV, INDE) entre 2022 e 2024, além do modelo preditivo de risco construído para antecipar aumento de IAN.</p>'
        + '<h2>Indicadores</h2><ul>' + ''.join([f'<li>{it}</li>' for it in key_insights]) + '</ul>'
        + '<h2>Análises efetuadas</h2><ul><li>Perfil e evolução da defasagem (IAN) por ano</li><li>Médias por Fase para IDA/IEG/IAA/IPS/IPP/IPV/INDE</li><li>Relações e correlações (IEG×IDA, IEG×IPV, IAA×IDA, IAA×IEG)</li><li>Boxplots por quartis de IPS e por categorias de IAN</li><li>Heatmap de correlação e regressão explicativa para INDE</li><li>Treino e avaliação de modelo preditivo de risco (RandomForest)</li></ul>'
        + '<h2>Insights (resumo)</h2><ul>'
        + '<li>Existem diferenças observáveis na defasagem (IAN) entre anos; alguns grupos apresentam tendência de piora.</li>'
        + '<li>Variáveis como IDA, IEG e IPS mostram associação com tendências de defasagem; recomenda-se monitoramento por fase.</li>'
        + '<li>O modelo de risco identifica perfis com maior probabilidade de aumento de IAN; validar com dados futuros antes de operacionalizar.</li>'
        + '</ul>'
        + '</body></html>')

# Gravando arquivos
open(html_path, 'w', encoding='utf-8').write(html)
open(md_path, 'w', encoding='utf-8').write('# Relatório — Tech Challenge (Passos)\n' + '\n'.join([f'- {it}' for it in key_insights]))

print('Gerado:', html_path, '|', md_path)
# Out:
# RELATÓRIOS
# Gerado: reports/Relatorio_TechChallenge_Passos.html | reports/Relatorio_TechChallenge_Passos.md
